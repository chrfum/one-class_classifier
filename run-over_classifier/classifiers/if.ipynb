# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
from sklearn.decomposition import PCA, TruncatedSVD, FastICA
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.pipeline import Pipeline
import itertools
import pickle
import logging

# %%
df = pd.read_csv("../data/run-over-dataset.csv")
print(df.shape)

columns_to_drop = ['VERBALE', 'DATA', 'Tot Testa', 'Tot Torace', 'Tot Addome', 'Tot Scheletro',
                    'Totale', 'Tot Volta cranica', 'Tot Base cranica', 
                    'Tot Neuroc.', 'Tot Splancnoc.', 'Tot Testa',
                    'Tot Tratto toracico', 'Tot Tratto lombare', 'Tot Rachide',
                    ' Totale coste', 'Sterno in toto', 'Tot Bacino', 'I costa dx', 'II costa dx',
                    'III costa dx', 'IV costa dx', 'V costa dx', 'VI costa dx', 'VII costa dx', 
                    'VIII costa dx', 'IX costa dx', 'X costa dx', 'XI costa dx', 'XII costa dx',
                    'I costa sx', 'II costa sx', 'III costa sx', 'IV costa sx', 'V costa sx', 
                    'VI costa sx', 'VII costa sx', 'VIII costa sx', 'IX costa sx', 
                    'X costa sx', 'XI costa sx', 'XII costa sx']

X = df.drop(columns=columns_to_drop)
print(X.shape)

X['ALTEZZA'] = [int(float(h.replace(',', '.'))*100) for h in X['ALTEZZA']]
X['PESO'] = [int(float(str(h).replace(',', '.'))) for h in X['PESO']]
X['BMI'] = [float(str(h).replace(',', '.')) for h in X['BMI']]

num_unique_values = X.nunique()
constant_columns = num_unique_values[num_unique_values == 1].index.tolist()

X = X.drop(columns=constant_columns)
X = X.T.drop_duplicates().T
print(X.shape)
# Out:
# (130, 367)
# (130, 326)
# (130, 274)

# %%
random_seed = 3355825

# %%
def add_record(df, record):
    new_record = pd.DataFrame(record, index=[0])
    df = pd.concat([df, new_record], ignore_index=True)
    return df

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

file_handler = logging.FileHandler('../logs/if_nested_cv.log')
file_handler.setLevel(logging.INFO)
file_handler.setFormatter(logging.Formatter('%(asctime)s - %(levelname)s - %(message)s'))

logger = logging.getLogger()

logger.handlers = []
logger.addHandler(file_handler)

# %%
def nested_cv(X, random_seed, decomposition, n_outer_folds=7, n_inner_folds=5, n_components=60, mod_selection_score=accuracy_score, positive_class=0):
    n_estimatorss = np.arange(50, 151, 50)
    contaminations = np.linspace(0.01, 0.5, 5)
    max_featuress = np.linspace(0.1, 1.0, 5)
    scalers = [StandardScaler(), MinMaxScaler(), RobustScaler()]
    
    best_params = {'n_estimators': 0, 'contamination': 0, 'max_features': 0, 'pca': 0, 'scaler': ''}
    accuracy_scores = []
    precision_scores = []
    recall_scores = []
    f1_scores = []
    best_overall_accuracy = 0
    best_overall_params = {'n_estimators': 0, 'contamination': 0, 'max_features': 0, 'pca': 0, 'scaler': ''}

    y = X['Mezzo'].values
    y = np.array([0. if x == positive_class else 1. for x in y], dtype=float)
    
    X = X.drop(columns='Mezzo').values

    outer_cv = StratifiedKFold(n_splits=n_outer_folds, shuffle=True, random_state=random_seed)
        
    for outer_cv_number, (train_idx, test_idx) in enumerate(outer_cv.split(X, y)):
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        inner_cv = StratifiedKFold(n_splits=n_inner_folds, shuffle=True, random_state=random_seed)

        best_score = 0
        best_decomp = decomposition
        best_scaler = StandardScaler()
        for inner_cv_number, (trainval_idx, valid_idx) in enumerate(inner_cv.split(X_train, y_train)):
            for params in itertools.product(n_estimatorss, contaminations, max_featuress, scalers):
                scaler = params[3]
                X_trainval, X_valid = X_train[trainval_idx], X_train[valid_idx]
                y_trainval, y_valid = y_train[trainval_idx], y_train[valid_idx]

                X_trainval_scaled = scaler.fit_transform(X_trainval)
                X_valid_scaled = scaler.transform(X_valid)
                
                decomp = decomposition(n_components=n_components)
                X_trainval_reduced = decomp.fit_transform(X_trainval_scaled)
                X_valid_reduced = decomp.transform(X_valid_scaled)

                idxs_neg = np.where(y_trainval == 1)[0]
                X_trainval_reduced = np.delete(X_trainval_reduced, idxs_neg, axis=0)
                y_trainval = np.delete(y_trainval, idxs_neg)

                clf = IsolationForest(n_estimators=params[0], contamination=params[1], max_features=params[2])
                    
                clf.fit(X_trainval_reduced)
                    
                pred_values = clf.predict(X_valid_reduced)
                true_values = [1 if y == 0 else -1 for y in y_valid]
                    
                score = mod_selection_score(true_values, pred_values)
                curr_params = {
                        'n_estimators': params[0],
                        'contamination': params[1],
                        'max_features': params[2],
                        'components': n_components,
                        'scaler': params[3]
                }

                logging.info(f"inner cv number: {inner_cv_number}, {mod_selection_score.__name__}: {score}, with params: {curr_params}")
                        
                if score > best_score:
                    best_score = score
                    best_decomposition = decomp
                    best_scaler = scaler
                    best_params = curr_params

        idxs_neg = np.where(y_train == 1)[0]
        X_train = np.delete(X_train, idxs_neg, axis=0)
        y_train = np.delete(y_train, idxs_neg)

        X_train_scaled = best_scaler.fit_transform(X_train)
        X_test_scaled = best_scaler.transform(X_test)

        X_train_reduced = best_decomposition.transform(X_train_scaled)
        X_test_reduced = best_decomposition.transform(X_test_scaled)

        clf = IsolationForest(n_estimators=best_params['n_estimators'], contamination=best_params['contamination'], max_features=best_params['max_features'])
        clf.fit(X_train_reduced)

        pred_values = clf.predict(X_test_reduced)
        true_values = [1 if y == 0 else -1 for y in y_test]

        accuracy = accuracy_score(true_values, pred_values)
        precision = precision_score(true_values, pred_values, zero_division=0.0)
        recall = recall_score(true_values, pred_values, zero_division=0.0)
        f1 = f1_score(true_values, pred_values, zero_division=0.0)

        if accuracy > best_overall_accuracy:
            best_overall_accuracy = accuracy
            best_overall_params = best_params

        logging.info(f"outer cv number: {outer_cv_number}, accuracy: {accuracy}, precision: {precision}, recall: {recall}, f1: {f1} with params: {best_params}")

        accuracy_scores.append(accuracy)
        precision_scores.append(precision)
        recall_scores.append(recall)
        f1_scores.append(f1)

    return {
        'algorythm': 'IsolationForest',
        'best n_estimators': best_overall_params['n_estimators'],
        'best contamination': best_overall_params['contamination'],
        'best max_features': best_overall_params['max_features'],
        'decomposition': decomposition,
        'n_components': best_overall_params['components'],
        'best scaler': best_overall_params['scaler'],
        'score used for model selection': mod_selection_score.__name__,
        'method used for model selection': 'nested cv',
        'accuracy mean': np.mean(accuracy_scores) * 100,
        'accuracy std': np.std(accuracy_scores) * 100,
        'precision mean': np.mean(precision_scores) * 100,
        'precision std': np.std(precision_scores) * 100,
        'recall mean': np.mean(recall_scores) * 100,
        'recall std': np.std(recall_scores) * 100,
        'f1 mean': np.mean(f1_scores) * 100,
        'f1 std': np.std(f1_scores) * 100,
        'best overall accuracy': best_overall_accuracy * 100,
        'class': positive_class
    }

# %%
results = nested_cv(X, random_seed, PCA, n_components=85, mod_selection_score=accuracy_score, positive_class=0)
scores_df = pd.DataFrame(results, index=[0])
scores_df
# Out:
#          algorythm  best n_estimators  best contamination  best max_features  \
# 0  IsolationForest                100              0.1325               0.55
#
#                               decomposition  n_components       best scaler  \
# 0  <class 'sklearn.decomposition._pca.PCA'>            85  StandardScaler()
#
#   score used for model selection method used for model selection  \
# 0                 accuracy_score                       nested cv
#
#    accuracy mean  accuracy std  precision mean  precision std  recall mean  \
# 0       68.71345     11.809184       67.615995       8.970701    81.428571
#
#    recall std    f1 mean     f1 std  best overall accuracy  class
# 0   22.314999  72.475482  12.812223              88.888889      0

# %%
for pca_comps in np.arange(80, 49, -5):
    scores_df = add_record(scores_df, nested_cv(X, random_seed, PCA, n_components=pca_comps, mod_selection_score=accuracy_score, positive_class=0))

scores_df
# Out:
#          algorythm  best n_estimators  best contamination  best max_features  \
# 0  IsolationForest                100              0.1325              0.550
# 1  IsolationForest                100              0.1325              1.000
# 2  IsolationForest                 50              0.3775              0.775
# 3  IsolationForest                 50              0.2550              0.775
# 4  IsolationForest                100              0.5000              1.000
# 5  IsolationForest                 50              0.5000              1.000
# 6  IsolationForest                100              0.5000              0.325
# 7  IsolationForest                 50              0.5000              0.325
#
#                               decomposition  n_components       best scaler  \
# 0  <class 'sklearn.decomposition._pca.PCA'>            85  StandardScaler()
# 1  <class 'sklearn.decomposition._pca.PCA'>            80    RobustScaler()
# 2  <class 'sklearn.decomposition._pca.PCA'>            75  StandardScaler()
# 3  <class 'sklearn.decomposition._pca.PCA'>            70    RobustScaler()
# 4  <class 'sklearn.decomposition._pca.PCA'>            65    RobustScaler()
# 5  <class 'sklearn.decomposition._pca.PCA'>            60    RobustScaler()
# 6  <class 'sklearn.decomposition._pca.PCA'>            55    RobustScaler()
# 7  <class 'sklearn.decomposition._pca.PCA'>            50    RobustScaler()
#
#   score used for model selection method used for model selection  \
# 0                 accuracy_score                       nested cv
# 1                 accuracy_score                       nested cv
# 2                 accuracy_score                       nested cv
# 3                 accuracy_score                       nested cv
# 4                 accuracy_score                       nested cv
# 5                 accuracy_score                       nested cv
# 6                 accuracy_score                       nested cv
# 7                 accuracy_score                       nested cv
#
#    accuracy mean  accuracy std  precision mean  precision std  recall mean  \
# 0      68.713450     11.809184       67.615995       8.970701    81.428571
# 1      62.489557     12.822433       63.238526      11.861377    71.428571
# 2      67.084378     10.876538       69.015152      10.127500    70.000000
# 3      65.413534      9.273747       66.038723       7.356919    72.857143
# 4      61.654135      9.406754       68.934240       8.583163    51.428571
# 5      64.745196     11.054750       69.890110      12.323075    60.000000
# 6      67.836257     13.904819       70.674088      11.229100    68.571429
# 7      65.455305      8.306253       67.380952       5.463235    68.571429
#
#    recall std    f1 mean     f1 std  best overall accuracy  class
# 0   22.314999  72.475482  12.812223              88.888889      0
# 1   20.995626  65.995350  14.963328              83.333333      0
# 2   13.093073  69.253437  11.100972              88.888889      0
# 3   17.496355  68.476877  11.201495              78.947368      0
# 4   20.303815  57.000178  15.272524              77.777778      0
# 5   20.000000  63.203934  14.871353              77.777778      0
# 6   26.418917  67.297828  17.196719              94.444444      0
# 7   22.946255  66.324144  12.360738              77.777778      0

# %%
for pca_comps in np.arange(85, 49, -5):
    scores_df = add_record(scores_df, nested_cv(X, random_seed, PCA, n_components=pca_comps, mod_selection_score=f1_score, positive_class=0))

scores_df
# Out:
#           algorythm  best n_estimators  best contamination  best max_features  \
# 0   IsolationForest                100              0.1325              0.550
# 1   IsolationForest                100              0.1325              1.000
# 2   IsolationForest                 50              0.3775              0.775
# 3   IsolationForest                 50              0.2550              0.775
# 4   IsolationForest                100              0.5000              1.000
# 5   IsolationForest                 50              0.5000              1.000
# 6   IsolationForest                100              0.5000              0.325
# 7   IsolationForest                 50              0.5000              0.325
# 8   IsolationForest                 50              0.1325              0.325
# 9   IsolationForest                 50              0.1325              0.100
# 10  IsolationForest                 50              0.5000              0.100
# 11  IsolationForest                100              0.3775              0.550
# 12  IsolationForest                150              0.2550              0.100
# 13  IsolationForest                100              0.5000              1.000
# 14  IsolationForest                100              0.5000              0.775
# 15  IsolationForest                 50              0.5000              0.325
#
#                                decomposition  n_components       best scaler  \
# 0   <class 'sklearn.decomposition._pca.PCA'>            85  StandardScaler()
# 1   <class 'sklearn.decomposition._pca.PCA'>            80    RobustScaler()
# 2   <class 'sklearn.decomposition._pca.PCA'>            75  StandardScaler()
# 3   <class 'sklearn.decomposition._pca.PCA'>            70    RobustScaler()
# 4   <class 'sklearn.decomposition._pca.PCA'>            65    RobustScaler()
# 5   <class 'sklearn.decomposition._pca.PCA'>            60    RobustScaler()
# 6   <class 'sklearn.decomposition._pca.PCA'>            55    RobustScaler()
# 7   <class 'sklearn.decomposition._pca.PCA'>            50    RobustScaler()
# 8   <class 'sklearn.decomposition._pca.PCA'>            85    MinMaxScaler()
# 9   <class 'sklearn.decomposition._pca.PCA'>            80    MinMaxScaler()
# 10  <class 'sklearn.decomposition._pca.PCA'>            75    MinMaxScaler()
# 11  <class 'sklearn.decomposition._pca.PCA'>            70    RobustScaler()
# 12  <class 'sklearn.decomposition._pca.PCA'>            65    RobustScaler()
# 13  <class 'sklearn.decomposition._pca.PCA'>            60    RobustScaler()
# 14  <class 'sklearn.decomposition._pca.PCA'>            55  StandardScaler()
# 15  <class 'sklearn.decomposition._pca.PCA'>            50    MinMaxScaler()
#
#    score used for model selection method used for model selection  \
# 0                  accuracy_score                       nested cv
# 1                  accuracy_score                       nested cv
# 2                  accuracy_score                       nested cv
# 3                  accuracy_score                       nested cv
# 4                  accuracy_score                       nested cv
# 5                  accuracy_score                       nested cv
# 6                  accuracy_score                       nested cv
# 7                  accuracy_score                       nested cv
# 8                        f1_score                       nested cv
# 9                        f1_score                       nested cv
# 10                       f1_score                       nested cv
# 11                       f1_score                       nested cv
# 12                       f1_score                       nested cv
# 13                       f1_score                       nested cv
# 14                       f1_score                       nested cv
# 15                       f1_score                       nested cv
#
#     accuracy mean  accuracy std  precision mean  precision std  recall mean  \
# 0       68.713450     11.809184       67.615995       8.970701    81.428571
# 1       62.489557     12.822433       63.238526      11.861377    71.428571
# 2       67.084378     10.876538       69.015152      10.127500    70.000000
# 3       65.413534      9.273747       66.038723       7.356919    72.857143
# 4       61.654135      9.406754       68.934240       8.583163    51.428571
# 5       64.745196     11.054750       69.890110      12.323075    60.000000
# 6       67.836257     13.904819       70.674088      11.229100    68.571429
# 7       65.455305      8.306253       67.380952       5.463235    68.571429
# 8       64.703425      7.091497       65.496805       8.148966    75.714286
# 9       66.332498     12.726550       70.772561      10.579093    64.285714
# 10      67.710944     12.023256       68.228536      11.889995    78.571429
# 11      67.084378      9.161307       68.071452       6.800082    74.285714
# 12      60.818713      8.785842       64.455782       6.799532    61.428571
# 13      67.084378     10.167294       68.861971       9.253439    70.000000
# 14      63.826232      8.092173       67.259724       5.584063    62.857143
# 15      60.776942      5.522322       63.991960       4.831831    64.285714
#
#     recall std    f1 mean     f1 std  best overall accuracy  class
# 0    22.314999  72.475482  12.812223              88.888889      0
# 1    20.995626  65.995350  14.963328              83.333333      0
# 2    13.093073  69.253437  11.100972              88.888889      0
# 3    17.496355  68.476877  11.201495              78.947368      0
# 4    20.303815  57.000178  15.272524              77.777778      0
# 5    20.000000  63.203934  14.871353              77.777778      0
# 6    26.418917  67.297828  17.196719              94.444444      0
# 7    22.946255  66.324144  12.360738              77.777778      0
# 8    14.982984  69.280702   8.046850              77.777778      0
# 9    21.946131  65.673752  14.631377              83.333333      0
# 10   14.568627  72.324580  10.687982              89.473684      0
# 11   21.946131  68.985911  13.570554              83.333333      0
# 12   16.413036  62.018460   9.308307              77.777778      0
# 13   14.142136  69.091570  10.882704              88.888889      0
# 14   20.503857  63.494064  12.686881              73.684211      0
# 15   19.166297  62.548423   9.076325              66.666667      0

# %%
file_path = '../pickles/if_df.pickle'

with open(file_path, "wb") as file:
    pickle.dump(scores_df, file)

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

file_handler = logging.FileHandler('../logs/if_svd_nested_cv.log')
file_handler.setLevel(logging.INFO)
file_handler.setFormatter(logging.Formatter('%(asctime)s - %(levelname)s - %(message)s'))

logger = logging.getLogger()

logger.handlers = []
logger.addHandler(file_handler)

# %%
for n_comps in np.arange(85, 49, -5):
    scores_df = add_record(scores_df, nested_cv(X, random_seed, TruncatedSVD, n_components=n_comps))

scores_df
# Out:
#           algorythm  best n_estimators  best contamination  best max_features  \
# 0   IsolationForest                100              0.1325              0.550
# 1   IsolationForest                100              0.1325              1.000
# 2   IsolationForest                 50              0.3775              0.775
# 3   IsolationForest                 50              0.2550              0.775
# 4   IsolationForest                100              0.5000              1.000
# 5   IsolationForest                 50              0.5000              1.000
# 6   IsolationForest                100              0.5000              0.325
# 7   IsolationForest                 50              0.5000              0.325
# 8   IsolationForest                 50              0.1325              0.325
# 9   IsolationForest                 50              0.1325              0.100
# 10  IsolationForest                 50              0.5000              0.100
# 11  IsolationForest                100              0.3775              0.550
# 12  IsolationForest                150              0.2550              0.100
# 13  IsolationForest                100              0.5000              1.000
# 14  IsolationForest                100              0.5000              0.775
# 15  IsolationForest                 50              0.5000              0.325
# 16  IsolationForest                 50              0.2550              0.100
# 17  IsolationForest                 50              0.3775              0.325
# 18  IsolationForest                 50              0.2550              0.325
# 19  IsolationForest                 50              0.2550              0.775
# 20  IsolationForest                150              0.5000              0.325
# 21  IsolationForest                100              0.5000              0.550
# 22  IsolationForest                 50              0.5000              0.325
# 23  IsolationForest                100              0.5000              1.000
#
#                                         decomposition  n_components  \
# 0            <class 'sklearn.decomposition._pca.PCA'>            85
# 1            <class 'sklearn.decomposition._pca.PCA'>            80
# 2            <class 'sklearn.decomposition._pca.PCA'>            75
# 3            <class 'sklearn.decomposition._pca.PCA'>            70
# 4            <class 'sklearn.decomposition._pca.PCA'>            65
# 5            <class 'sklearn.decomposition._pca.PCA'>            60
# 6            <class 'sklearn.decomposition._pca.PCA'>            55
# 7            <class 'sklearn.decomposition._pca.PCA'>            50
# 8            <class 'sklearn.decomposition._pca.PCA'>            85
# 9            <class 'sklearn.decomposition._pca.PCA'>            80
# 10           <class 'sklearn.decomposition._pca.PCA'>            75
# 11           <class 'sklearn.decomposition._pca.PCA'>            70
# 12           <class 'sklearn.decomposition._pca.PCA'>            65
# 13           <class 'sklearn.decomposition._pca.PCA'>            60
# 14           <class 'sklearn.decomposition._pca.PCA'>            55
# 15           <class 'sklearn.decomposition._pca.PCA'>            50
# 16  <class 'sklearn.decomposition._truncated_svd.T...            85
# 17  <class 'sklearn.decomposition._truncated_svd.T...            80
# 18  <class 'sklearn.decomposition._truncated_svd.T...            75
# 19  <class 'sklearn.decomposition._truncated_svd.T...            70
# 20  <class 'sklearn.decomposition._truncated_svd.T...            65
# 21  <class 'sklearn.decomposition._truncated_svd.T...            60
# 22  <class 'sklearn.decomposition._truncated_svd.T...            55
# 23  <class 'sklearn.decomposition._truncated_svd.T...            50
#
#          best scaler score used for model selection  \
# 0   StandardScaler()                 accuracy_score
# 1     RobustScaler()                 accuracy_score
# 2   StandardScaler()                 accuracy_score
# 3     RobustScaler()                 accuracy_score
# 4     RobustScaler()                 accuracy_score
# 5     RobustScaler()                 accuracy_score
# 6     RobustScaler()                 accuracy_score
# 7     RobustScaler()                 accuracy_score
# 8     MinMaxScaler()                       f1_score
# 9     MinMaxScaler()                       f1_score
# 10    MinMaxScaler()                       f1_score
# 11    RobustScaler()                       f1_score
# 12    RobustScaler()                       f1_score
# 13    RobustScaler()                       f1_score
# 14  StandardScaler()                       f1_score
# 15    MinMaxScaler()                       f1_score
# 16  StandardScaler()                 accuracy_score
# 17    RobustScaler()                 accuracy_score
# 18    MinMaxScaler()                 accuracy_score
# 19    RobustScaler()                 accuracy_score
# 20    RobustScaler()                 accuracy_score
# 21    RobustScaler()                 accuracy_score
# 22  StandardScaler()                 accuracy_score
# 23    RobustScaler()                 accuracy_score
#
#    method used for model selection  accuracy mean  accuracy std  \
# 0                        nested cv      68.713450     11.809184
# 1                        nested cv      62.489557     12.822433
# 20  18.329953              83.333333      0
# 21  16.470605              83.333333      0
# 22  15.054383              83.333333      0
# 23  11.802675              77.777778      0

# %%
for n_comps in np.arange(85, 49, -5):
    scores_df = add_record(scores_df, nested_cv(X, random_seed, TruncatedSVD, n_components=n_comps, mod_selection_score=f1_score))

scores_df
# Out:
#           algorythm  best n_estimators  best contamination  best max_features  \
# 0   IsolationForest                100              0.1325              0.550
# 1   IsolationForest                100              0.1325              1.000
# 2   IsolationForest                 50              0.3775              0.775
# 3   IsolationForest                 50              0.2550              0.775
# 4   IsolationForest                100              0.5000              1.000
# 5   IsolationForest                 50              0.5000              1.000
# 6   IsolationForest                100              0.5000              0.325
# 7   IsolationForest                 50              0.5000              0.325
# 8   IsolationForest                 50              0.1325              0.325
# 9   IsolationForest                 50              0.1325              0.100
# 10  IsolationForest                 50              0.5000              0.100
# 11  IsolationForest                100              0.3775              0.550
# 12  IsolationForest                150              0.2550              0.100
# 13  IsolationForest                100              0.5000              1.000
# 14  IsolationForest                100              0.5000              0.775
# 15  IsolationForest                 50              0.5000              0.325
# 16  IsolationForest                 50              0.2550              0.100
# 17  IsolationForest                 50              0.3775              0.325
# 18  IsolationForest                 50              0.2550              0.325
# 19  IsolationForest                 50              0.2550              0.775
# 20  IsolationForest                150              0.5000              0.325
# 21  IsolationForest                100              0.5000              0.550
# 22  IsolationForest                 50              0.5000              0.325
# 23  IsolationForest                100              0.5000              1.000
# 24  IsolationForest                100              0.3775              0.550
# 25  IsolationForest                100              0.2550              0.550
# 26  IsolationForest                100              0.3775              0.550
# 27  IsolationForest                 50              0.3775              1.000
# 28  IsolationForest                150              0.5000              0.100
# 29  IsolationForest                 50              0.5000              1.000
# 30  IsolationForest                 50              0.3775              1.000
# 31  IsolationForest                150              0.1325              0.100
#
#                                         decomposition  n_components  \
# 0            <class 'sklearn.decomposition._pca.PCA'>            85
# 1            <class 'sklearn.decomposition._pca.PCA'>            80
# 2            <class 'sklearn.decomposition._pca.PCA'>            75
# 3            <class 'sklearn.decomposition._pca.PCA'>            70
# 4            <class 'sklearn.decomposition._pca.PCA'>            65
# 5            <class 'sklearn.decomposition._pca.PCA'>            60
# 6            <class 'sklearn.decomposition._pca.PCA'>            55
# 7            <class 'sklearn.decomposition._pca.PCA'>            50
# 8            <class 'sklearn.decomposition._pca.PCA'>            85
# 9            <class 'sklearn.decomposition._pca.PCA'>            80
# 10           <class 'sklearn.decomposition._pca.PCA'>            75
# 11           <class 'sklearn.decomposition._pca.PCA'>            70
# 12           <class 'sklearn.decomposition._pca.PCA'>            65
# 13           <class 'sklearn.decomposition._pca.PCA'>            60
# 14           <class 'sklearn.decomposition._pca.PCA'>            55
# 15           <class 'sklearn.decomposition._pca.PCA'>            50
# 16  <class 'sklearn.decomposition._truncated_svd.T...            85
# 17  <class 'sklearn.decomposition._truncated_svd.T...            80
# 18  <class 'sklearn.decomposition._truncated_svd.T...            75
# 19  <class 'sklearn.decomposition._truncated_svd.T...            70
# 20  <class 'sklearn.decomposition._truncated_svd.T...            65
# 21  <class 'sklearn.decomposition._truncated_svd.T...            60
# 22  <class 'sklearn.decomposition._truncated_svd.T...            55
# 23  <class 'sklearn.decomposition._truncated_svd.T...            50
# 24  <class 'sklearn.decomposition._truncated_svd.T...            85
# 25  <class 'sklearn.decomposition._truncated_svd.T...            80
# 26  <class 'sklearn.decomposition._truncated_svd.T...            75
# 27  <class 'sklearn.decomposition._truncated_svd.T...            70
# 28  <class 'sklearn.decomposition._truncated_svd.T...            65
# 29  <class 'sklearn.decomposition._truncated_svd.T...            60
# 30  <class 'sklearn.decomposition._truncated_svd.T...            55
# 31  <class 'sklearn.decomposition._truncated_svd.T...            50
#
#          best scaler score used for model selection  \
# 0   StandardScaler()                 accuracy_score
# 1     RobustScaler()                 accuracy_score
# 2   StandardScaler()                 accuracy_score
# 3     RobustScaler()                 accuracy_score
# 4     RobustScaler()                 accuracy_score
# 5     RobustScaler()                 accuracy_score
# 6     RobustScaler()                 accuracy_score
# 7     RobustScaler()                 accuracy_score
# 8     MinMaxScaler()                       f1_score
# 9     MinMaxScaler()                       f1_score
# 10    MinMaxScaler()                       f1_score
# 11    RobustScaler()                       f1_score
# 12    RobustScaler()                       f1_score
# 13    RobustScaler()                       f1_score
# 14  StandardScaler()                       f1_score
# 15    MinMaxScaler()                       f1_score
# 16  StandardScaler()                 accuracy_score
# 17    RobustScaler()                 accuracy_score
# 18    MinMaxScaler()                 accuracy_score
# 19    RobustScaler()                 accuracy_score
# 20    RobustScaler()                 accuracy_score
# 21    RobustScaler()                 accuracy_score
# 22  StandardScaler()                 accuracy_score
# 23    RobustScaler()                 accuracy_score
# 24  StandardScaler()                       f1_score
# 25    RobustScaler()                       f1_score
# 26    RobustScaler()                       f1_score
# 27    RobustScaler()                       f1_score
# 28    RobustScaler()                       f1_score
# 29    RobustScaler()                       f1_score
# 30    RobustScaler()                       f1_score
# 31    RobustScaler()                       f1_score
#
#    method used for model selection  accuracy mean  accuracy std  \
# 0                        nested cv      68.713450     11.809184
# 1                        nested cv      62.489557     12.822433
# 2                        nested cv      67.084378     10.876538
# 3                        nested cv      65.413534      9.273747
# 4                        nested cv      61.654135      9.406754
# 5                        nested cv      64.745196     11.054750
# 6                        nested cv      67.836257     13.904819
# 7                        nested cv      65.455305      8.306253
# 8                        nested cv      64.703425      7.091497
# 9                        nested cv      66.332498     12.726550
# 10                       nested cv      67.710944     12.023256
# 11                       nested cv      67.084378      9.161307
# 12                       nested cv      60.818713      8.785842
# 13                       nested cv      67.084378     10.167294
# 14                       nested cv      63.826232      8.092173
# 15                       nested cv      60.776942      5.522322
# 16                       nested cv      63.157895     11.063743
# 17                       nested cv      66.374269     10.382617
# 18                       nested cv      67.752715      3.469265
# 19                       nested cv      66.290727      8.039172
# 20                       nested cv      63.868003     14.177826
# 21                       nested cv      64.035088     11.872106
# 22                       nested cv      68.504595     11.329596
# 23                       nested cv      67.042607      7.258321
# 24                       nested cv      66.416040     15.336193
# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

file_handler = logging.FileHandler('../logs/if_fastica_nested_cv.log')
file_handler.setLevel(logging.INFO)
file_handler.setFormatter(logging.Formatter('%(asctime)s - %(levelname)s - %(message)s'))

logger = logging.getLogger()

logger.handlers = []
logger.addHandler(file_handler)

# %%
for n_comps in np.arange(85, 49, -5):
    scores_df = add_record(scores_df, nested_cv(X, random_seed, FastICA, n_components=n_comps))

scores_df
# Out:
#           algorythm  best n_estimators  best contamination  best max_features  \
# 0   IsolationForest                100              0.1325              0.550
# 1   IsolationForest                100              0.1325              1.000
# 2   IsolationForest                 50              0.3775              0.775
# 3   IsolationForest                 50              0.2550              0.775
# 4   IsolationForest                100              0.5000              1.000
# 5   IsolationForest                 50              0.5000              1.000
# 6   IsolationForest                100              0.5000              0.325
# 7   IsolationForest                 50              0.5000              0.325
# 8   IsolationForest                 50              0.1325              0.325
# 9   IsolationForest                 50              0.1325              0.100
# 10  IsolationForest                 50              0.5000              0.100
# 11  IsolationForest                100              0.3775              0.550
# 12  IsolationForest                150              0.2550              0.100
# 13  IsolationForest                100              0.5000              1.000
# 14  IsolationForest                100              0.5000              0.775
# 15  IsolationForest                 50              0.5000              0.325
# 16  IsolationForest                 50              0.2550              0.100
# 17  IsolationForest                 50              0.3775              0.325
# 18  IsolationForest                 50              0.2550              0.325
# 19  IsolationForest                 50              0.2550              0.775
# 20  IsolationForest                150              0.5000              0.325
# 21  IsolationForest                100              0.5000              0.550
# 22  IsolationForest                 50              0.5000              0.325
# 23  IsolationForest                100              0.5000              1.000
# 24  IsolationForest                100              0.3775              0.550
# 25  IsolationForest                100              0.2550              0.550
# 26  IsolationForest                100              0.3775              0.550
# 27  IsolationForest                 50              0.3775              1.000
# 28  IsolationForest                150              0.5000              0.100
# 29  IsolationForest                 50              0.5000              1.000
# 30  IsolationForest                 50              0.3775              1.000
# 31  IsolationForest                150              0.1325              0.100
# 32  IsolationForest                 50              0.0100              0.775
# 33  IsolationForest                100              0.0100              1.000
# 34  IsolationForest                100              0.0100              0.775
# 35  IsolationForest                 50              0.0100              0.550
# 36  IsolationForest                 50              0.0100              0.100
# 37  IsolationForest                100              0.1325              0.325
# 38  IsolationForest                100              0.1325              0.550
# 39  IsolationForest                100              0.1325              0.325
#
#                                         decomposition  n_components  \
# 0            <class 'sklearn.decomposition._pca.PCA'>            85
# 1            <class 'sklearn.decomposition._pca.PCA'>            80
# 2            <class 'sklearn.decomposition._pca.PCA'>            75
# 3            <class 'sklearn.decomposition._pca.PCA'>            70
# 4            <class 'sklearn.decomposition._pca.PCA'>            65
# 5            <class 'sklearn.decomposition._pca.PCA'>            60
# 6            <class 'sklearn.decomposition._pca.PCA'>            55
# 7            <class 'sklearn.decomposition._pca.PCA'>            50
# 8            <class 'sklearn.decomposition._pca.PCA'>            85
# 9            <class 'sklearn.decomposition._pca.PCA'>            80
# 10           <class 'sklearn.decomposition._pca.PCA'>            75
# 11           <class 'sklearn.decomposition._pca.PCA'>            70
# 12           <class 'sklearn.decomposition._pca.PCA'>            65
# 13           <class 'sklearn.decomposition._pca.PCA'>            60
# 14           <class 'sklearn.decomposition._pca.PCA'>            55
# 15           <class 'sklearn.decomposition._pca.PCA'>            50
# 16  <class 'sklearn.decomposition._truncated_svd.T...            85
# 17  <class 'sklearn.decomposition._truncated_svd.T...            80
# 18  <class 'sklearn.decomposition._truncated_svd.T...            75
# 19  <class 'sklearn.decomposition._truncated_svd.T...            70
# 20  <class 'sklearn.decomposition._truncated_svd.T...            65
# 21  <class 'sklearn.decomposition._truncated_svd.T...            60
# 22  <class 'sklearn.decomposition._truncated_svd.T...            55
# 23  <class 'sklearn.decomposition._truncated_svd.T...            50
# 24  <class 'sklearn.decomposition._truncated_svd.T...            85
# 25  <class 'sklearn.decomposition._truncated_svd.T...            80
# 26  <class 'sklearn.decomposition._truncated_svd.T...            75
# 27  <class 'sklearn.decomposition._truncated_svd.T...            70
# 28  <class 'sklearn.decomposition._truncated_svd.T...            65
# 29  <class 'sklearn.decomposition._truncated_svd.T...            60
# 30  <class 'sklearn.decomposition._truncated_svd.T...            55
# 31  <class 'sklearn.decomposition._truncated_svd.T...            50
# 32   <class 'sklearn.decomposition._fastica.FastICA'>            85
# 33   <class 'sklearn.decomposition._fastica.FastICA'>            80
# 34   <class 'sklearn.decomposition._fastica.FastICA'>            75
# 35   <class 'sklearn.decomposition._fastica.FastICA'>            70
# 36   <class 'sklearn.decomposition._fastica.FastICA'>            65
# 37   <class 'sklearn.decomposition._fastica.FastICA'>            60
# 38   <class 'sklearn.decomposition._fastica.FastICA'>            55
# 39   <class 'sklearn.decomposition._fastica.FastICA'>            50
#
#          best scaler score used for model selection  \
# 0   StandardScaler()                 accuracy_score
# 1     RobustScaler()                 accuracy_score
# 2   StandardScaler()                 accuracy_score
# 3     RobustScaler()                 accuracy_score
# 4     RobustScaler()                 accuracy_score
# 5     RobustScaler()                 accuracy_score
# 6     RobustScaler()                 accuracy_score
# 7     RobustScaler()                 accuracy_score
# 8     MinMaxScaler()                       f1_score
# 9     MinMaxScaler()                       f1_score
# 10    MinMaxScaler()                       f1_score
# 11    RobustScaler()                       f1_score
# 12    RobustScaler()                       f1_score
# 13    RobustScaler()                       f1_score
# 14  StandardScaler()                       f1_score
# 15    MinMaxScaler()                       f1_score
# 16  StandardScaler()                 accuracy_score
# 17    RobustScaler()                 accuracy_score
# 18    MinMaxScaler()                 accuracy_score
# 19    RobustScaler()                 accuracy_score
# 20    RobustScaler()                 accuracy_score
# 21    RobustScaler()                 accuracy_score
# 22  StandardScaler()                 accuracy_score
# 23    RobustScaler()                 accuracy_score
# 24  StandardScaler()                       f1_score
# 25    RobustScaler()                       f1_score
# 26    RobustScaler()                       f1_score
# 27    RobustScaler()                       f1_score
# 28    RobustScaler()                       f1_score
# 29    RobustScaler()                       f1_score
# 30    RobustScaler()                       f1_score
# 31    RobustScaler()                       f1_score
# 32    MinMaxScaler()                 accuracy_score
# 33    MinMaxScaler()                 accuracy_score
# 34  StandardScaler()                 accuracy_score
# 35    RobustScaler()                 accuracy_score
# 36  StandardScaler()                 accuracy_score
# 37    MinMaxScaler()                 accuracy_score
# 38  StandardScaler()                 accuracy_score
# 39  StandardScaler()                 accuracy_score
#
#    method used for model selection  accuracy mean  accuracy std  \
# 0                        nested cv      68.713450     11.809184
# 1                        nested cv      62.489557     12.822433
# 2                        nested cv      67.084378     10.876538
# 3                        nested cv      65.413534      9.273747
# 4                        nested cv      61.654135      9.406754
# 5                        nested cv      64.745196     11.054750
# 6                        nested cv      67.836257     13.904819
# 7                        nested cv      65.455305      8.306253
# 8                        nested cv      64.703425      7.091497
# 9                        nested cv      66.332498     12.726550
# 10                       nested cv      67.710944     12.023256
# 11                       nested cv      67.084378      9.161307
# 12                       nested cv      60.818713      8.785842
# 13                       nested cv      67.084378     10.167294
# 14                       nested cv      63.826232      8.092173
# 15                       nested cv      60.776942      5.522322
# 16                       nested cv      63.157895     11.063743
# 17                       nested cv      66.374269     10.382617
# 18                       nested cv      67.752715      3.469265
# 19                       nested cv      66.290727      8.039172
# 20                       nested cv      63.868003     14.177826
# 21                       nested cv      64.035088     11.872106
# 22                       nested cv      68.504595     11.329596
# 23                       nested cv      67.042607      7.258321
# 24                       nested cv      66.416040     15.336193
# 25                       nested cv      65.538847     12.185280
# 26                       nested cv      66.917293     13.611353
# 27                       nested cv      64.035088     13.308798
# 28                       nested cv      66.248956     12.619987
# 29                       nested cv      66.290727      9.352435
# 30                       nested cv      65.497076      9.521061
# 31                       nested cv      64.619883      7.008836
# 32                       nested cv      56.975773      3.287467
# 33                       nested cv      61.445280      5.103942
# 34                       nested cv      60.776942      6.806253
# 35                       nested cv      57.727652      2.768891
# 36                       nested cv      58.479532      7.667926
# 37                       nested cv      60.944027     11.170156
# 38                       nested cv      64.619883     12.050798
# 39                       nested cv      62.489557     12.892728
#
#     precision mean  precision std  recall mean  recall std    f1 mean  \
# 0        67.615995       8.970701    81.428571   22.314999  72.475482
# 1        63.238526      11.861377    71.428571   20.995626  65.995350
# 2        69.015152      10.127500    70.000000   13.093073  69.253437
# 3        66.038723       7.356919    72.857143   17.496355  68.476877
# 4        68.934240       8.583163    51.428571   20.303815  57.000178
# 5        69.890110      12.323075    60.000000   20.000000  63.203934
# 6        70.674088      11.229100    68.571429   26.418917  67.297828
# 7        67.380952       5.463235    68.571429   22.946255  66.324144
# 8        65.496805       8.148966    75.714286   14.982984  69.280702
# 9        70.772561      10.579093    64.285714   21.946131  65.673752
# 10       68.228536      11.889995    78.571429   14.568627  72.324580
# 11       68.071452       6.800082    74.285714   21.946131  68.985911
# 12       64.455782       6.799532    61.428571   16.413036  62.018460
# 13       68.861971       9.253439    70.000000   14.142136  69.091570
#           algorythm  best n_estimators  best contamination  best max_features  \
# 0   IsolationForest                100              0.1325              0.550
# 1   IsolationForest                100              0.1325              1.000
# 2   IsolationForest                 50              0.3775              0.775
# 3   IsolationForest                 50              0.2550              0.775
# 4   IsolationForest                100              0.5000              1.000
# 5   IsolationForest                 50              0.5000              1.000
# 6   IsolationForest                100              0.5000              0.325
# 7   IsolationForest                 50              0.5000              0.325
# 8   IsolationForest                 50              0.1325              0.325
# 9   IsolationForest                 50              0.1325              0.100
# 10  IsolationForest                 50              0.5000              0.100
# 11  IsolationForest                100              0.3775              0.550
# 12  IsolationForest                150              0.2550              0.100
# 13  IsolationForest                100              0.5000              1.000
# 14  IsolationForest                100              0.5000              0.775
# 15  IsolationForest                 50              0.5000              0.325
# 16  IsolationForest                 50              0.2550              0.100
# 17  IsolationForest                 50              0.3775              0.325
# 18  IsolationForest                 50              0.2550              0.325
# 19  IsolationForest                 50              0.2550              0.775
# 20  IsolationForest                150              0.5000              0.325
# 21  IsolationForest                100              0.5000              0.550
# 22  IsolationForest                 50              0.5000              0.325
# 23  IsolationForest                100              0.5000              1.000
# 24  IsolationForest                100              0.3775              0.550
# 25  IsolationForest                100              0.2550              0.550
# 26  IsolationForest                100              0.3775              0.550
# 27  IsolationForest                 50              0.3775              1.000
# 28  IsolationForest                150              0.5000              0.100
# 29  IsolationForest                 50              0.5000              1.000
# 30  IsolationForest                 50              0.3775              1.000
# 31  IsolationForest                150              0.1325              0.100
# 32  IsolationForest                 50              0.0100              0.775
# 33  IsolationForest                100              0.0100              1.000
# 34  IsolationForest                100              0.0100              0.775
# 35  IsolationForest                 50              0.0100              0.550
# 36  IsolationForest                 50              0.0100              0.100
# 37  IsolationForest                100              0.1325              0.325
# 38  IsolationForest                100              0.1325              0.550
# 39  IsolationForest                100              0.1325              0.325
# 40  IsolationForest                 50              0.0100              0.775
# 41  IsolationForest                 50              0.0100              0.775
# 42  IsolationForest                100              0.0100              0.775
# 43  IsolationForest                 50              0.0100              0.550
# 44  IsolationForest                150              0.0100              0.550
# 45  IsolationForest                 50              0.1325              0.550
# 46  IsolationForest                150              0.2550              0.325
# 47  IsolationForest                100              0.1325              0.100
#
#                                         decomposition  n_components  \
# 0            <class 'sklearn.decomposition._pca.PCA'>            85
# 1            <class 'sklearn.decomposition._pca.PCA'>            80
# 2            <class 'sklearn.decomposition._pca.PCA'>            75
# 3            <class 'sklearn.decomposition._pca.PCA'>            70
# 4            <class 'sklearn.decomposition._pca.PCA'>            65
# 5            <class 'sklearn.decomposition._pca.PCA'>            60
# 6            <class 'sklearn.decomposition._pca.PCA'>            55
# 7            <class 'sklearn.decomposition._pca.PCA'>            50
# 8            <class 'sklearn.decomposition._pca.PCA'>            85
# 9            <class 'sklearn.decomposition._pca.PCA'>            80
# 10           <class 'sklearn.decomposition._pca.PCA'>            75
# 11           <class 'sklearn.decomposition._pca.PCA'>            70
# 12           <class 'sklearn.decomposition._pca.PCA'>            65
# 13           <class 'sklearn.decomposition._pca.PCA'>            60
# 14           <class 'sklearn.decomposition._pca.PCA'>            55
# 15           <class 'sklearn.decomposition._pca.PCA'>            50
# 16  <class 'sklearn.decomposition._truncated_svd.T...            85
# 17  <class 'sklearn.decomposition._truncated_svd.T...            80
# 18  <class 'sklearn.decomposition._truncated_svd.T...            75
# 19  <class 'sklearn.decomposition._truncated_svd.T...            70
# 20  <class 'sklearn.decomposition._truncated_svd.T...            65
# 21  <class 'sklearn.decomposition._truncated_svd.T...            60
# 22  <class 'sklearn.decomposition._truncated_svd.T...            55
# 23  <class 'sklearn.decomposition._truncated_svd.T...            50
# 24  <class 'sklearn.decomposition._truncated_svd.T...            85
# 25  <class 'sklearn.decomposition._truncated_svd.T...            80
# 26  <class 'sklearn.decomposition._truncated_svd.T...            75
# 27  <class 'sklearn.decomposition._truncated_svd.T...            70
# 28  <class 'sklearn.decomposition._truncated_svd.T...            65
# 29  <class 'sklearn.decomposition._truncated_svd.T...            60
# 30  <class 'sklearn.decomposition._truncated_svd.T...            55
# 31  <class 'sklearn.decomposition._truncated_svd.T...            50
# 32   <class 'sklearn.decomposition._fastica.FastICA'>            85
# 33   <class 'sklearn.decomposition._fastica.FastICA'>            80
# 34   <class 'sklearn.decomposition._fastica.FastICA'>            75
# 35   <class 'sklearn.decomposition._fastica.FastICA'>            70
# 36   <class 'sklearn.decomposition._fastica.FastICA'>            65
# 37   <class 'sklearn.decomposition._fastica.FastICA'>            60
# 38   <class 'sklearn.decomposition._fastica.FastICA'>            55
# 39   <class 'sklearn.decomposition._fastica.FastICA'>            50
# 40   <class 'sklearn.decomposition._fastica.FastICA'>            85
# 41   <class 'sklearn.decomposition._fastica.FastICA'>            80
# 42   <class 'sklearn.decomposition._fastica.FastICA'>            75
# 43   <class 'sklearn.decomposition._fastica.FastICA'>            70
# 44   <class 'sklearn.decomposition._fastica.FastICA'>            65
# 45   <class 'sklearn.decomposition._fastica.FastICA'>            60
# 46   <class 'sklearn.decomposition._fastica.FastICA'>            55
# 47   <class 'sklearn.decomposition._fastica.FastICA'>            50
#
#          best scaler score used for model selection  \
# 0   StandardScaler()                 accuracy_score
# 1     RobustScaler()                 accuracy_score
# 2   StandardScaler()                 accuracy_score
# 3     RobustScaler()                 accuracy_score
# 4     RobustScaler()                 accuracy_score
# 5     RobustScaler()                 accuracy_score
# 6     RobustScaler()                 accuracy_score
# 7     RobustScaler()                 accuracy_score
# 8     MinMaxScaler()                       f1_score
# 9     MinMaxScaler()                       f1_score
# 10    MinMaxScaler()                       f1_score
# 11    RobustScaler()                       f1_score
# 12    RobustScaler()                       f1_score
# 13    RobustScaler()                       f1_score
# 14  StandardScaler()                       f1_score
# 15    MinMaxScaler()                       f1_score
# 16  StandardScaler()                 accuracy_score
# 17    RobustScaler()                 accuracy_score
# 18    MinMaxScaler()                 accuracy_score
# 19    RobustScaler()                 accuracy_score
# 20    RobustScaler()                 accuracy_score
# 21    RobustScaler()                 accuracy_score
# 22  StandardScaler()                 accuracy_score
# 23    RobustScaler()                 accuracy_score
# 24  StandardScaler()                       f1_score
# 25    RobustScaler()                       f1_score
# 26    RobustScaler()                       f1_score
# 27    RobustScaler()                       f1_score
# 28    RobustScaler()                       f1_score
# 29    RobustScaler()                       f1_score
# 30    RobustScaler()                       f1_score
# 31    RobustScaler()                       f1_score
# 32    MinMaxScaler()                 accuracy_score
# 33    MinMaxScaler()                 accuracy_score
# 34  StandardScaler()                 accuracy_score
# 35    RobustScaler()                 accuracy_score
# 36  StandardScaler()                 accuracy_score
# 37    MinMaxScaler()                 accuracy_score
# 38  StandardScaler()                 accuracy_score
# 39  StandardScaler()                 accuracy_score
# 40  StandardScaler()                       f1_score
# 41    MinMaxScaler()                       f1_score
# 42  StandardScaler()                       f1_score
# 43  StandardScaler()                       f1_score
# 44    RobustScaler()                       f1_score
# 45  StandardScaler()                       f1_score
# 46    MinMaxScaler()                       f1_score
# 47  StandardScaler()                       f1_score
#
#    method used for model selection  accuracy mean  accuracy std  \
# 0                        nested cv      68.713450     11.809184
# 1                        nested cv      62.489557     12.822433
# 2                        nested cv      67.084378     10.876538
# 3                        nested cv      65.413534      9.273747
# 4                        nested cv      61.654135      9.406754
# 5                        nested cv      64.745196     11.054750
# 6                        nested cv      67.836257     13.904819
# 7                        nested cv      65.455305      8.306253
# 8                        nested cv      64.703425      7.091497
# 9                        nested cv      66.332498     12.726550
# 10                       nested cv      67.710944     12.023256
# 11                       nested cv      67.084378      9.161307
# 12                       nested cv      60.818713      8.785842
# 13                       nested cv      67.084378     10.167294
# 14                       nested cv      63.826232      8.092173
# 15                       nested cv      60.776942      5.522322
# 16                       nested cv      63.157895     11.063743
# 17                       nested cv      66.374269     10.382617
# 18                       nested cv      67.752715      3.469265
# 19                       nested cv      66.290727      8.039172
# 20                       nested cv      63.868003     14.177826
# 21                       nested cv      64.035088     11.872106
# 22                       nested cv      68.504595     11.329596
# 23                       nested cv      67.042607      7.258321
# 24                       nested cv      66.416040     15.336193
# 25                       nested cv      65.538847     12.185280
# 26                       nested cv      66.917293     13.611353
# 27                       nested cv      64.035088     13.308798
# 28                       nested cv      66.248956     12.619987
# 29                       nested cv      66.290727      9.352435
# 30                       nested cv      65.497076      9.521061
# 31                       nested cv      64.619883      7.008836
# 32                       nested cv      56.975773      3.287467
# 33                       nested cv      61.445280      5.103942
# 34                       nested cv      60.776942      6.806253
# 35                       nested cv      57.727652      2.768891
# 36                       nested cv      58.479532      7.667926
# 37                       nested cv      60.944027     11.170156
# 38                       nested cv      64.619883     12.050798
# 39                       nested cv      62.489557     12.892728
# 40                       nested cv      62.364244      9.286908
# 41                       nested cv      59.314954      4.878821
# 42                       nested cv      61.695906      9.492797
# 43                       nested cv      63.074353      7.929030
# 44                       nested cv      63.157895      7.448150
# 45                       nested cv      56.140351      4.467359
# 46                       nested cv      60.735171      8.268356
# 47                       nested cv      61.152882     18.671913
#
#     precision mean  precision std  recall mean  recall std    f1 mean  \
# 7   12.360738              77.777778      0
# 8    8.046850              77.777778      0
# 9   14.631377              83.333333      0
# 10  10.687982              89.473684      0
# 11  13.570554              83.333333      0
# 12   9.308307              77.777778      0
# 13  10.882704              88.888889      0
# 14  12.686881              73.684211      0
# 15   9.076325              66.666667      0
# 16  14.372579              77.777778      0
# 17  13.355802              83.333333      0
# 18   5.700787              72.222222      0
# 19  11.375577              83.333333      0
# 20  18.329953              83.333333      0
# 21  16.470605              83.333333      0
# 22  15.054383              83.333333      0
# 23  11.802675              77.777778      0
# 24  16.681913              94.444444      0
# 25  15.731609              88.888889      0
# 26  14.986814              84.210526      0
# 27  15.062392              88.888889      0
# 28  13.969274              83.333333      0
# 29   8.683129              77.777778      0
# 30  12.305243              83.333333      0
# 31   6.513220              77.777778      0
# 32   2.086728              61.111111      0
# 33   1.981922              68.421053      0
# 34   6.696467              72.222222      0
# 35   2.887754              61.111111      0
# 36  11.934346              68.421053      0
# 37  16.549572              77.777778      0
# 38  12.679709              88.888889      0
# 39  13.175527              88.888889      0
# 40   5.131650              77.777778      0
# 41   2.987270              66.666667      0
# 42   6.222485              77.777778      0
# 43   4.562954              77.777778      0
# 44   4.959480              77.777778      0
# 45   8.603151              63.157895      0
# 46  12.895912              72.222222      0
# 47  22.923655              94.444444      0

# %%
file_path = '../pickles/if_df.pickle'

with open(file_path, "wb") as file:
    pickle.dump(scores_df, file)

# %%
def plot_components(X):
    components = []
    variance = []

    for pca_comps in np.arange(1, 101, 1):
        pca = PCA(n_components=pca_comps)
        X_temp = X.drop(columns='Mezzo').values
        pca.fit_transform(X_temp)

        components.append(pca_comps)
        variance.append(np.sum(pca.explained_variance_ratio_))
    
    plt.figure(figsize=(10, 6))
    plt.plot(components, variance, marker='o', linestyle='--', color='b')
    plt.title('Varianza totale spiegata dai componenti principali')
    plt.xlabel('Numero di Componenti Principali')
    plt.ylabel('Varianza spiegata cumulativa')
    plt.show()

# %%
plot_components(X)

# %%
def plot_error_bar(df, n_init, n_end, decomposition, score):
    df = df.iloc[n_init:n_end+1]
    n_comps = df['n_components']
    accuracy_mean = df['accuracy mean']
    accuracy_std = df['accuracy std']

    plt.figure(figsize=(10, 6))
    plt.errorbar(n_comps, accuracy_mean, yerr=accuracy_std, fmt='o', linestyle='--', color='b', ecolor='r', capsize=5)
    plt.title('Accuratezza con ' + decomposition + ' usando ' + score + " per la model selection")
    plt.xlabel('Numero di Componenti Principali')
    plt.ylabel('Accuratezza')
    plt.ylim(0,100)
    plt.show()

# %%
plot_error_bar(scores_df, 0, 7, 'PCA', 'accuracy_score')

# %%
plot_error_bar(scores_df, 8, 15, 'PCA', 'f1_score')

# %%
plot_error_bar(scores_df, 16, 23, 'TruncatedSVD', 'accuracy_score')

# %%
plot_error_bar(scores_df, 24, 31, 'TruncatedSVD', 'f1_score')

# %%
plot_error_bar(scores_df, 32, 39, 'FastICA', 'accuracy_score')

# %%
plot_error_bar(scores_df, 40, 47, 'FastICA', 'f1_score')
